# %% [markdown]
# # Capstone Project: The Battle of Neighborhoods (Week1)

# %% [markdown]
# # Introduction:

# %% [markdown]
# My friend, named as Nilo, who plan to set-up a Chicken Rice Restaurant has asked for help to determine which neighborhood in Toronto city is the most ideal place for his 1st set-up
#
# Proposed company website
#
# https://yangschicken.ca
#
# I have arrange a high tea with Nilo to discuss further on 26.12.2020

# %% [markdown]
# # Problem Description:

# %% [markdown]
# Which neighborhood should my friend, Nilo, open his Chicken Rice Restaurant in Toronto?
#
# Since this is his 1st shop, Nilo wants to ensure profit making and sustainable business.

# %% [markdown]
# # Requirements:

# %% [markdown]
# **1. SELECTION OF LOCATION
# This is the most important part. We need to ensure it is strategically located inside the biggest concentration of restaurants in Toronto area.**
#
# **2. MODELLING AND EVALUATING
# We can make assumption via modelling and evaluating the model. We can visually cluster common restaurants in Toronto by neighborhood.**
#
# **3.
# We need to determine that a good number people can visit these restaurants with sustainable visit inside these neighborhoods.**
#
# a.) Is the neighborhood populous?
#
# b.) Is the neighborhood average salary close to the Canadian National Average?

# %% [markdown]
# Beside this, My friend, Nilo wants to be able to predict which neighborhoods is tend to have a growing number of restaurants in next few years
#
# Locating his new store according to these requirements will ensure the following:
# * lowest cost for DELIVERY
# * shortest travel time his clients for DINE IN
# * overall lower OPERATION COST
# * increase in REVENUE

# %%
End (27.12.2020)
# Out:
#   File "<ipython-input-1-37b731ce63ca>", line 1
#     End (27.12.2020)
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# End (27.12.2020)
